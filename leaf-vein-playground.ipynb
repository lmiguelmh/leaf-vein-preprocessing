# %% [markdown]
# #### Playground

# %%
% matplotlib inline

import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import scipy.fftpack
import hf
import filters
import contours
import contrast

# img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ag1-ag10\\ag1.tif"
img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ig1-ig3\\ig1.tif"
# img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ig1-ig3\\ig2.tif"
operation = ""

operation += "+gray"
gray = cv2.imread(img_path, 0)  # gray-scale loading
gray = gray.T
h, w = gray.shape
cv2.imwrite(img_path + operation + ".jpg", gray)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray, interpolation='none', cmap='gray')
plt.show()

operation += "+gamma"
gray = contrast.adjust_gamma(gray, 10.)
cv2.imwrite(img_path + operation + ".jpg", gray)

# operation += "+equ"
# gray = cv2.equalizeHist(gray)
# cv2.imwrite(img_path + operation + ".jpg", gray)

# operation += "+gblur"
# gray = cv2.GaussianBlur(gray, (5, 5) ,0)
# operation += "+median"
# gray = cv2.medianBlur(gray, 3)
# operation += "+blur"
# gray = cv2.blur(gray, (2, 2), borderType=cv2.BORDER_REPLICATE)
# operation += "+bilateral"
# window_size = (h>>3)
# gray = cv2.bilateralFilter(gray, window_size, 30, window_size)
# cv2.imwrite(img_path + operation + ".jpg", gray)

# operation += "+dog"
# g1 = cv2.GaussianBlur(gray, (3, 3), 0);
# g2 = cv2.GaussianBlur(gray, (7, 7), 0);
# gray = g1 - g2;
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+hessian"
# from skimage.feature import hessian_matrix, hessian_matrix_eigvals
# hxx, hxy, hyy = hessian_matrix(gray, sigma=3.0)
# gray, _ = hessian_matrix_eigvals(hxx, hxy, hyy)
# gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+fft"
# rows, cols = gray.shape
# M = rows + 1
# N = cols + 1
# sigma = 20
# filt, low, high = hf.hfilter(gray, M, N, sigma, 1.0, 1.0)
# cv2.imwrite(img_path + operation + "low.jpg", low)
# cv2.imwrite(img_path + operation + "high.jpg", high)
# gray = high
# # operation += "+fft2"
# # rows, cols = gray.shape
# # M = rows + 1
# # N = cols + 1
# # sigma = 20
# # filt, low, high = hf.hfilter2(gray, M, N, sigma, 1.0, 1.0)
# # cv2.imwrite(img_path + operation + "low.jpg", low)
# # cv2.imwrite(img_path + operation + "high.jpg", high)
# # gray = filt
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+sobel"
# gray = filters.sobel_filter(gray)
operation += "+kirsch"
gray = filters.kirsch_filter(gray)
# operation += "+laplacian"
# gray = cv2.Laplacian(gray, cv2.CV_64F)
# gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
cv2.imwrite(img_path + operation + ".jpg", gray)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray, interpolation='none', cmap='gray')
plt.show()

# operation += "+gamma"
# gray = contrast.adjust_gamma(gray, 0.2)
# cv2.imwrite(img_path + operation + ".jpg", gray)

# # operation += "+gblur"
# # gray = cv2.GaussianBlur(gray, (5, 5) ,0)
# # cv2.imwrite(img_path + operation + ".jpg", gray)
# # operation += "+median"
# # gray = cv2.medianBlur(gray, 3)
# # cv2.imwrite(img_path + operation + ".jpg", gray)
# # operation += "+blur"
# # gray = cv2.blur(gray, (3, 3), borderType=cv2.BORDER_REPLICATE)
# # cv2.imwrite(img_path + operation + ".jpg", gray)
# operation += "+bilateral"
# window_size = (h>>4)
# # gray = cv2.bilateralFilter(gray, window_size, 5, window_size)
# gray = cv2.bilateralFilter(gray, 7, 7, 7)
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+equ"
# gray = cv2.equalizeHist(gray)
# cv2.imwrite(img_path + operation + ".jpg", gray)

# operation += "+fft"
# rows, cols = gray.shape
# M = rows + 1
# N = cols + 1
# sigma = 20
# _, _, gray = hf.hfilter(gray, M, N, sigma, 1.0, 2.0)
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+hessian"
# from skimage.feature import hessian_matrix, hessian_matrix_eigvals
# hxx, hxy, hyy = hessian_matrix(gray, sigma=1.0)
# gray, _ = hessian_matrix_eigvals(hxx, hxy, hyy)
# gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
# cv2.imwrite(img_path + operation + ".jpg", gray)
# plt.figure(figsize=(12, 12))
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.imshow(gray, interpolation='none', cmap='gray')
# plt.show()

# operation += "+canny"
# gray_bin = filters.auto_canny(gray, 0.1)
# operation += "+otsu"
# _, gray_bin = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY_INV)
operation += "+adaptive"
# window_size = (h>>1) + 1
# window_size = (h >> 1) + (1 - ((h >> 1) % 2))
window_size = (h) + (1 - ((h) % 2))
gray_bin = cv2.adaptiveThreshold(gray, 255, cv2.THRESH_BINARY_INV, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, window_size, 0)
# operation += "+adaptive.mean"
# window_size = (h>>1) + 1
# gray_bin = cv2.adaptiveThreshold(gray, 255, cv2.THRESH_BINARY_INV, cv2.ADAPTIVE_THRESH_MEAN_C, window_size, 0)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()


operation += "+del"
_, cnts, _ = cv2.findContours(gray_bin, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_SIMPLE)
mask = np.zeros((h, w), np.uint8)
for i, cnt in enumerate(cnts):
    contour_area = cv2.contourArea(cnt)
    if contour_area < 30:
        cv2.drawContours(mask, cnts, i, (255, 255, 255), cv2.FILLED, 8)
plt.figure(figsize=(12, 12))
plt.imshow(mask, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()
gray_bin = cv2.bitwise_or(gray_bin, mask)


# operation += "+clean"
# gray_bin = contours.clean_img_bin(gray_bin, h*w*0.05, h*w*0.90, 50)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray_bin, interpolation='none', cmap='gray')
plt.show()

# # img_bin = cv2.bitwise_not(gray_bin)
# img_bin = gray_bin
# min_area = h*w*0.1
# max_area = h*w*0.9
# border_radius = 50
# _, character_contours, _ = cv2.findContours(img_bin, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_SIMPLE)
# mask = np.zeros((h, w), np.uint8)
# for i, character_cnt in enumerate(character_contours):
#     rx, ry, rw, rh = cv2.boundingRect(character_cnt)
#     rxf = rx + rw - 1
#     ryf = ry + rh - 1
#     contour_area = cv2.contourArea(character_cnt)
#     has_right_area = min_area < contour_area < max_area
#     close_to_border = rxf < border_radius or ryf < border_radius or rx + border_radius > w or ry + border_radius > h
#     if has_right_area and not close_to_border:
#         cv2.drawContours(mask, character_contours, i, (255, 255, 255), -1, 8)
# plt.figure(figsize=(12, 12))
# plt.imshow(mask, cmap = 'gray', interpolation='none')
# plt.title("contours"), plt.xticks([]), plt.yticks([])
# plt.show()

# operation += "+dilation"
# gray_bin = cv2.erode(gray_bin, cv2.getStructuringElement(cv2.MORPH_ERODE, (2, 2)), iterations=1)
# cv2.imwrite(img_path + operation + ".jpg", gray_bin)
# plt.figure(figsize=(12, 12))
# plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.show()

# # operation += "+erode"
# # gray_bin = cv2.dilate(gray_bin, cv2.getStructuringElement(cv2.MORPH_ERODE, (2, 2)), iterations=1)
# operation += "+closing"
# gray_bin = cv2.morphologyEx(gray_bin, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2)))
# # gray_bin = cv2.erode(gray_bin, cv2.getStructuringElement(cv2.MORPH_ERODE, (3, 3)), iterations=1)
# cv2.imwrite(img_path + operation + ".jpg", gray_bin)
# plt.figure(figsize=(12, 12))
# plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.show()

from skimage import img_as_bool, io, color, morphology, img_as_ubyte
operation += "+skel"
# gray_bin[gray_bin==255] = 0
# gray_bin[gray_bin!=255] = 1
gray_bin = cv2.bitwise_not(gray_bin)
gray_bin = morphology.medial_axis(gray_bin)
gray_bin = img_as_ubyte(gray_bin)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()

# from skimage import img_as_bool, io, color, morphology
# operation += "+skel"
# gray_bin[gray_bin==255] = 1
# gray_bin[gray_bin!=255] = 0
# gray_bin = morphology.skeletonize(gray_bin)
# # gray_bin = cv2.normalize(gray_bin, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
# # cv2.imwrite(img_path + operation + ".jpg", gray_bin)
# plt.figure(figsize=(12, 12))
# plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.show()



# operation += "+open"
# gray_bin1 = gray_bin
# gray_bin = cv2.morphologyEx(gray_bin, cv2.MORPH_OPEN, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (4, 4)))
# # operation += "+close"
# # gray_bin1 = gray_bin
# # gray_bin = cv2.morphologyEx(gray_bin, cv2.MORPH_CLOSE, cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (4, 4)))
# cv2.imwrite(img_path + operation + ".jpg", gray_bin)
# plt.figure(figsize=(12, 12))
# plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.show()

# operation += "+sub"
# gray_bin = gray_bin1 + cv2.bitwise_not(gray_bin)
# cv2.imwrite(img_path + operation + ".jpg", gray_bin)
# plt.figure(figsize=(12, 12))
# plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
# plt.title(operation), plt.xticks([]), plt.yticks([])
# plt.show()

# %%
% matplotlib inline

import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import scipy.fftpack
import hf
import filters
import contours
import contrast

img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ag1-ag10\\ag1.tif"
# img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ig1-ig3\\ig1.tif"
img_path = "D:\\projects\\leaf-vein-segmentation\\doc\\problem\\hojas\\ig1-ig3\\ig2.tif"
operation = ""

operation += "+gray"
gray = cv2.imread(img_path, 0)  # gray-scale loading
gray = gray.T
h, w = gray.shape
cv2.imwrite(img_path + operation + ".jpg", gray)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray, interpolation='none', cmap='gray')
plt.show()

operation += "+gamma"
gray = contrast.adjust_gamma(gray, 10.)
cv2.imwrite(img_path + operation + ".jpg", gray)

# operation += "+sobel"
# gray = filters.sobel_filter(gray)
operation += "+kirsch"
gray = filters.kirsch_filter(gray)
# operation += "+laplacian"
# gray = cv2.Laplacian(gray, cv2.CV_64F)
# gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)
cv2.imwrite(img_path + operation + ".jpg", gray)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray, interpolation='none', cmap='gray')
plt.show()

# operation += "+canny"
# gray_bin = filters.auto_canny(gray, 0.1)
# operation += "+otsu"
# _, gray_bin = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU + cv2.THRESH_BINARY_INV)
operation += "+adaptive"
# window_size = (h>>1) + 1
# window_size = (h >> 1) + (1 - ((h >> 1) % 2))
window_size = (h) + (1 - ((h) % 2))
gray_bin = cv2.adaptiveThreshold(gray, 255, cv2.THRESH_BINARY_INV, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, window_size, 0)
# operation += "+adaptive.mean"
# window_size = (h>>1) + 1
# gray_bin = cv2.adaptiveThreshold(gray, 255, cv2.THRESH_BINARY_INV, cv2.ADAPTIVE_THRESH_MEAN_C, window_size, 0)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()


operation += "+del"
_, cnts, _ = cv2.findContours(gray_bin, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_SIMPLE)
mask = np.zeros((h, w), np.uint8)
for i, cnt in enumerate(cnts):
    contour_area = cv2.contourArea(cnt)
    if contour_area < 30:
        cv2.drawContours(mask, cnts, i, (255, 255, 255), cv2.FILLED, 8)
plt.figure(figsize=(12, 12))
plt.imshow(mask, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()
# gray_bin = cv2.bitwise_or(gray_bin, gray_bin, mask=(mask))
gray_bin = gray_bin+mask


# operation += "+clean"
# gray_bin = contours.clean_img_bin(gray_bin, h*w*0.05, h*w*0.90, 50)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.imshow(gray_bin, interpolation='none', cmap='gray')
plt.show()


from skimage import img_as_bool, io, color, morphology, img_as_ubyte
operation += "+skel"
# gray_bin[gray_bin==255] = 0
# gray_bin[gray_bin!=255] = 1
gray_bin = cv2.bitwise_not(gray_bin)
gray_bin = morphology.medial_axis(gray_bin)
gray_bin = img_as_ubyte(gray_bin)
cv2.imwrite(img_path + operation + ".jpg", gray_bin)
plt.figure(figsize=(12, 12))
plt.imshow(gray_bin, cmap = 'gray', interpolation='none')
plt.title(operation), plt.xticks([]), plt.yticks([])
plt.show()
